# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
test_data = pd.read_csv('./data/FIFA_test.csv')
train_data = pd.read_csv('./data/FIFA_train.csv')

# %% [markdown]
# ### FIFA_train.csv
#
#
# |변수명|변수 설명|변수 타입|타입 설명|
# |:---:|:---:|:---:|:---:|
# |**id**|선수의 고유의 아이디| int||
# |**name**             | 이름                                               | string|
# |**age**              | 나이                                               | int|15세부터 40세
# |**continent**        | 선수들의 국적이 포함되어 있는 대륙                 | string|5개 대륙
# |**contract_until**   | 선수의 계약기간                                    | object||
# |**position**         | 선수가 선호하는 포지션 ex) 공격수, 수비수 등       | object|4개의 범주 구성(GK,DF,MF,ST)
# |**prefer_foot**      | 선수가 선호하는 발 ex) 오른발                      | object|2개의 범주 구성(왼발,오른발)
# |**reputation**       | 선수가 유명한 정도 ex) 높은 수치일 수록 유명한 선수|float|1.0부터 5.0까지 구성 - 5단계
# |**stat_overall**     | 선수의 현재 능력치                                 | int||
# |**stat_potential**   | 선수가 경험 및 노력을 통해 발전할 수 있는 정도     | int||
# |**stat_skill_moves** | 선수의 개인기 능력치                               |float|1.0부터 5.0까지 구성 - 5단계
# |**value**            | FIFA가 선정한 선수의 이적 시장 가격 (단위 : 유로)  |float||

# %%
train_data.head()
# Out:
#    id          name  age      continent contract_until position prefer_foot  \
# 0   0      L. Messi   31  south america           2021       ST        left
# 1   3        De Gea   27         europe           2020       GK       right
# 2   7     L. Suárez   31  south america           2021       ST       right
# 3   8  Sergio Ramos   32         europe           2020       DF       right
# 4   9      J. Oblak   25         europe           2021       GK       right
#
#    reputation  stat_overall  stat_potential  stat_skill_moves        value
# 0         5.0            94              94               4.0  110500000.0
# 1         4.0            91              93               1.0   72000000.0
# 2         5.0            91              91               3.0   80000000.0
# 3         4.0            91              91               3.0   51000000.0
# 4         3.0            90              93               1.0   68000000.0

# %%
test_data.head()
# Out:
#    id               name  age      continent contract_until position  \
# 0   1  Cristiano Ronaldo   33         europe           2022       ST
# 1   2          Neymar Jr   26  south america           2022       ST
# 2   4       K. De Bruyne   27         europe           2023       MF
# 3   5          E. Hazard   27         europe           2020       ST
# 4   6          L. Modrić   32         europe           2020       MF
#
#   prefer_foot  reputation  stat_overall  stat_potential  stat_skill_moves
# 0       right         5.0            94              94               5.0
# 1       right         5.0            92              93               5.0
# 2       right         4.0            91              92               4.0
# 3       right         4.0            91              91               4.0
# 4       right         4.0            91              91               4.0

# %% [markdown]
# 능력치가 같더라도 포지션,나이에 따라서 value의 가치가 다른지 확인하기
#
# 인기에따라 value가 다른지 확인하기
#
# 각 변수별 가중치,중요도 여부
#
# value 간략하게 할 방법 찾기

# %% [markdown]
# ### 2. 변수별 정보 확인

# %%
# 변수별 na값 확인
pd.DataFrame(train_data.isnull().sum())
# Out:
#                   0
# id                0
# name              0
# age               0
# continent         0
# contract_until    0
# position          0
# prefer_foot       0
# reputation        0
# stat_overall      0
# stat_potential    0
# stat_skill_moves  0
# value             0

# %%
# 변수별 정보 확인
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8932 entries, 0 to 8931
# Data columns (total 12 columns):
# id                  8932 non-null int64
# name                8932 non-null object
# age                 8932 non-null int64
# continent           8932 non-null object
# contract_until      8932 non-null object
# position            8932 non-null object
# prefer_foot         8932 non-null object
# reputation          8932 non-null float64
# stat_overall        8932 non-null int64
# stat_potential      8932 non-null int64
# stat_skill_moves    8932 non-null float64
# value               8932 non-null float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 837.5+ KB

# %%
# 중복된 데이터 확인

train_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3. name을 인덱스로

# %%
# 고유 번호 삭제
train_data = train_data[train_data.columns[1:]]

# %%
# 이름을 인덱스로 지정
train_data.rename(index = train_data['name'],inplace = True)
train_data = train_data[train_data.columns[1:]]

# %%
train_data.head()
# Out:
#               age      continent contract_until position prefer_foot  \
# L. Messi       31  south america           2021       ST        left
# De Gea         27         europe           2020       GK       right
# L. Suárez      31  south america           2021       ST       right
# Sergio Ramos   32         europe           2020       DF       right
# J. Oblak       25         europe           2021       GK       right
#
#               reputation  stat_overall  stat_potential  stat_skill_moves  \
# L. Messi             5.0            94              94               4.0
# De Gea               4.0            91              93               1.0
# L. Suárez            5.0            91              91               3.0
# Sergio Ramos         4.0            91              91               3.0
# J. Oblak             3.0            90              93               1.0
#
#                     value
# L. Messi      110500000.0
# De Gea         72000000.0
# L. Suárez      80000000.0
# Sergio Ramos   51000000.0
# J. Oblak       68000000.0

# %%
train_data.describe()
# Out:
#                age   reputation  stat_overall  stat_potential  \
# count  8932.000000  8932.000000   8932.000000     8932.000000
# mean     25.209136     1.130878     67.091133       71.997201
# std       4.635515     0.423792      6.854910        5.988147
# min      16.000000     1.000000     47.000000       48.000000
# 25%      21.000000     1.000000     63.000000       68.000000
# 50%      25.000000     1.000000     67.000000       72.000000
# 75%      28.000000     1.000000     72.000000       76.000000
# max      40.000000     5.000000     94.000000       94.000000
#
#        stat_skill_moves         value
# count       8932.000000  8.932000e+03
# mean           2.401702  2.778673e+06
# std            0.776048  5.840982e+06
# min            1.000000  1.000000e+04
# 25%            2.000000  3.750000e+05
# 50%            2.000000  8.250000e+05
# 75%            3.000000  2.600000e+06
# max            5.000000  1.105000e+08

# %% [markdown]
# ### 4. 변수 요약

# %% [markdown]
# ### 4.1 cut age pivot table

# %%
# 나이 15-19,20-24,25-29,30-34,35-39,40으로 분리
# include_lowest는 객체의 가장 작은 값을 포함 여부를 지정하는 것으로 기본값은 False로서 포함하지않음. 
# right = False이면 위 함수의 결과중의 한 구간을 (a, b]로 표시함.
# false(default)일 경우 a<x<b라는 의미 , True일 경우 [a, b] 즉,  a<x<=b

group_names = ['15-19', '20-24','25-29','30-34','35-39','40']

cut_age =  pd.cut(train_data['age'],[14,19,24,29,34,39,41], right= True, labels = group_names)

cut_age
# Out:
# L. Messi              30-34
# De Gea                25-29
# L. Suárez             30-34
# Sergio Ramos          30-34
# J. Oblak              25-29
# D. Godín              30-34
# David Silva           30-34
# N. Kanté              25-29
# M. ter Stegen         25-29
# T. Courtois           25-29
# Sergio Busquets       25-29
# E. Cavani             30-34
# M. Neuer              30-34
# G. Chiellini          30-34
# M. Salah              25-29
# Casemiro              25-29
# L. Insigne            25-29
# Isco                  25-29
# Coutinho              25-29
# P. Aubameyang         25-29
# M. Hummels            25-29
# H. Lloris             30-34
# G. Higuaín            30-34
# G. Buffon                40
# S. Umtiti             20-24
# K. Koulibaly          25-29
# P. Pogba              25-29
# R. Lukaku             25-29
# Jordi Alba            25-29
# D. Mertens            30-34
#                       ...
# M. Schantl            15-19
# P. Paya               15-19
# E. Bilen              15-19
# S. Dawood             15-19
# J. Granlund           15-19
# B. Arapovic           15-19
# P. Żyra               20-24
# H. Bernat             15-19
# V. Smedsrud           15-19
# O. Ollikainen         15-19
# G. Tegue              15-19
# J. Lindstrøm          15-19
# M. Al Qaydhi          20-24
# G. Figliuzzi          15-19
# N. Stephan            15-19
# J. Garcia Sossa       15-19
# M. Harsman            15-19
# J. Yabur              15-19
# M. Dyrmose            15-19
# T. Lawal              15-19
# D. Szczepaniak        15-19
# T. Gundelund          15-19
# M. Frøkjær-Jensen     15-19
# Nicolas Firmino       15-19
# Y. Uchimura           30-34
# S. Adewusi            15-19
# C. Ehlich             15-19
# N. Fuentes            15-19
# J. Milli              15-19
# N. Christoffersson    15-19
# Name: age, Length: 8932, dtype: category
# Categories (6, object): [15-19 < 20-24 < 25-29 < 30-34 < 35-39 < 40]

# %%
pd.value_counts(cut_age)
# Out:
# 20-24    3244
# 25-29    2947
# 30-34    1526
# 15-19     984
# 35-39     228
# 40          3
# Name: age, dtype: int64

# %%
# train_data에 적용
train_data['cut_age'] = cut_age
train_data.head()
# Out:
#               age      continent contract_until position prefer_foot  \
# L. Messi       31  south america           2021       ST        left
# De Gea         27         europe           2020       GK       right
# L. Suárez      31  south america           2021       ST       right
# Sergio Ramos   32         europe           2020       DF       right
# J. Oblak       25         europe           2021       GK       right
#
#               reputation  stat_overall  stat_potential  stat_skill_moves  \
# L. Messi             5.0            94              94               4.0
# De Gea               4.0            91              93               1.0
# L. Suárez            5.0            91              91               3.0
# Sergio Ramos         4.0            91              91               3.0
# J. Oblak             3.0            90              93               1.0
#
#                     value cut_age
# L. Messi      110500000.0   30-34
# De Gea         72000000.0   25-29
# L. Suárez      80000000.0   30-34
# Sergio Ramos   51000000.0   30-34
# J. Oblak       68000000.0   25-29

# %%
# 40세인 선수만
train_data[train_data['age'] == 40]
# Out:
#              age      continent contract_until position prefer_foot  \
# G. Buffon     40         europe           2019       GK       right
# S. Bertoli    40  south america           2019       GK       right
# B. Castillo   40  south america           2021       GK       right
#
#              reputation  stat_overall  stat_potential  stat_skill_moves  \
# G. Buffon           4.0            88              88               1.0
# S. Bertoli          1.0            73              73               1.0
# B. Castillo         1.0            66              66               1.0
#
#                  value cut_age
# G. Buffon    4000000.0      40
# S. Bertoli    270000.0      40
# B. Castillo    40000.0      40

# %%
# 나이 간략하게 범주화 시킬것

pos_pivot = train_data.pivot_table(values = 'value' , index = 'position', columns = 'cut_age', aggfunc = np.mean, fill_value = 0)

pos_pivot.round(2)
# Out:
# cut_age       15-19       20-24       25-29       30-34       35-39  \
# position
# DF        702062.50  2170379.81  2877910.37  2352071.82   782685.19
# GK        632790.70   956472.30  4008547.79  2611527.78   414814.81
# MF        728157.22  2996117.10  4105202.46  3347390.51   552327.59
# ST        808083.70  2824937.69  4402847.99  4740039.22  1958714.29
#
# cut_age           40
# position
# DF              0.00
# GK        1436666.67
# MF              0.00
# ST              0.00

# %% [markdown]
# ### 4.2 cut overall pivot table

# %%
# 스텟 간략하게 범주화
group_name = ['46-49','50-59','60-69','70-79','80-89','90-94']

cut_overall =  pd.cut(train_data['stat_overall'],[46,49,59,69,79,89,94], right= True, labels = group_name)

cut_overall
# Out:
# L. Messi              90-94
# De Gea                90-94
# L. Suárez             90-94
# Sergio Ramos          90-94
# J. Oblak              90-94
# D. Godín              90-94
# David Silva           90-94
# N. Kanté              80-89
# M. ter Stegen         80-89
# T. Courtois           80-89
# Sergio Busquets       80-89
# E. Cavani             80-89
# M. Neuer              80-89
# G. Chiellini          80-89
# M. Salah              80-89
# Casemiro              80-89
# L. Insigne            80-89
# Isco                  80-89
# Coutinho              80-89
# P. Aubameyang         80-89
# M. Hummels            80-89
# H. Lloris             80-89
# G. Higuaín            80-89
# G. Buffon             80-89
# S. Umtiti             80-89
# K. Koulibaly          80-89
# P. Pogba              80-89
# R. Lukaku             80-89
# Jordi Alba            80-89
# D. Mertens            80-89
#                       ...
# M. Schantl            50-59
# P. Paya               50-59
# E. Bilen              50-59
# S. Dawood             50-59
# J. Granlund           50-59
# B. Arapovic           50-59
# P. Żyra               50-59
# H. Bernat             50-59
# V. Smedsrud           50-59
# O. Ollikainen         50-59
# G. Tegue              50-59
# J. Lindstrøm          50-59
# M. Al Qaydhi          50-59
# G. Figliuzzi          46-49
# N. Stephan            46-49
# J. Garcia Sossa       46-49
# M. Harsman            46-49
# J. Yabur              46-49
# M. Dyrmose            46-49
# T. Lawal              46-49
# D. Szczepaniak        46-49
# T. Gundelund          46-49
# M. Frøkjær-Jensen     46-49
# Nicolas Firmino       46-49
# Y. Uchimura           46-49
# S. Adewusi            46-49
# C. Ehlich             46-49
# N. Fuentes            46-49
# J. Milli              46-49
# N. Christoffersson    46-49
# Name: stat_overall, Length: 8932, dtype: category
# Categories (6, object): [46-49 < 50-59 < 60-69 < 70-79 < 80-89 < 90-94]

# %%
pd.value_counts(cut_overall)
# Out:
# 60-69    4619
# 70-79    2837
# 50-59    1126
# 80-89     326
# 46-49      17
# 90-94       7
# Name: stat_overall, dtype: int64

# %%
# 스텟 간략하게 범주화 시킬것

train_data['cut_overall'] = cut_overall

# %%
pos_pivot = train_data.pivot_table(values = 'value' , index = 'cut_overall', columns = 'position', aggfunc = np.mean, fill_value = 0)

pos_pivot.round(2)
# Out:
# position              DF           GK           MF           ST
# cut_overall
# 46-49           47500.00     51666.67     53333.33     60000.00
# 50-59          146518.52    113916.67    164324.32    178397.13
# 60-69          600517.02    473855.04    719806.58    780232.16
# 70-79         4141144.91   3353107.00   5128044.43   5375415.13
# 80-89        19704819.28  19512195.12  25675373.13  27176470.59
# 90-94        47500000.00  70000000.00  60000000.00  95250000.00

# %%
pos_pivot.plot()
plt.show()

# %% [markdown]
# 70대 능력치까진 value는 비슷했으나 70중반부터는 포지션별 차이가 커짐을 알 수 있었다.
#
# 대체적으로 value의 값은 ST > MF > DF > GK순이였으나, GK의 능력치가 85~94 부분에서 DF와 MF보다 높음을 알 수 있었다.

# %%
# 능력치 80이 넘는 선수중 GK만
# isin를 통해 position에서 gk를 가지고 있는 행만 출력하도록 함.
# 총 35명의 선수들로 구성

stat_gk = train_data[train_data['stat_overall']> 80]
stat_gk[stat_gk['position'].isin(['GK'])].describe().round(2)
# Out:
#          age  reputation  stat_overall  stat_potential  stat_skill_moves  \
# count  35.00       35.00         35.00           35.00              35.0
# mean   28.83        2.66         84.11           85.86               1.0
# std     3.96        0.94          2.75            3.44               0.0
# min    19.00        1.00         81.00           82.00               1.0
# 25%    26.00        2.00         82.00           83.00               1.0
# 50%    28.00        3.00         83.00           84.00               1.0
# 75%    31.00        3.00         84.50           88.00               1.0
# max    40.00        5.00         91.00           93.00               1.0
#
#              value
# count        35.00
# mean   24685714.29
# std    16412909.96
# min     3000000.00
# 25%    14500000.00
# 50%    20000000.00
# 75%    29250000.00
# max    72000000.00

# %%
# 능력치 80이 넘는 선수중 DF만
stat_df = train_data[train_data['stat_overall']> 80]
stat_df[stat_df['position'].isin(['DF'])].describe().round(2)
# Out:
#          age  reputation  stat_overall  stat_potential  stat_skill_moves  \
# count  58.00       58.00         58.00           58.00             58.00
# mean   28.02        2.69         83.47           85.22              2.41
# std     3.92        0.73          2.47            3.11              0.62
# min    18.00        1.00         81.00           81.00              2.00
# 25%    25.00        2.00         82.00           83.00              2.00
# 50%    29.00        3.00         83.00           85.00              2.00
# 75%    31.00        3.00         85.00           87.75              3.00
# max    35.00        4.00         91.00           92.00              4.00
#
#              value
# count        58.00
# mean   24418965.52
# std    11892581.45
# min     4800000.00
# 25%    17500000.00
# 50%    21000000.00
# 75%    31125000.00
# max    57000000.00

# %%
# 능력치 80이 넘는 선수중 MF만
stat_mf = train_data[train_data['stat_overall']> 80]
stat_mf[stat_mf['position'].isin(['MF'])].describe().round(2)
# Out:
#           age  reputation  stat_overall  stat_potential  stat_skill_moves  \
# count  103.00      103.00        103.00          103.00            103.00
# mean    27.40        2.61         83.27           84.86              3.59
# std      3.23        0.76          2.11            2.80              0.81
# min     21.00        1.00         81.00           81.00              2.00
# 25%     25.00        2.00         82.00           83.00              3.00
# 50%     27.00        3.00         83.00           84.00              4.00
# 75%     30.00        3.00         84.00           87.00              4.00
# max     34.00        4.00         90.00           91.00              5.00
#
#              value
# count       103.00
# mean   29291262.14
# std    13339188.23
# min     8000000.00
# 25%    19750000.00
# 50%    26000000.00
# 75%    34500000.00
# max    69500000.00

# %% [markdown]
# ### 4.3 contract 요약

# %%
train_data['contract_until'] = train_data['contract_until'].apply(lambda x : str(x)).apply(lambda x : x[-4:])
train_data
# Out:
#                     age      continent contract_until position prefer_foot  \
# L. Messi             31  south america           2021       ST        left
# De Gea               27         europe           2020       GK       right
# L. Suárez            31  south america           2021       ST       right
# Sergio Ramos         32         europe           2020       DF       right
# J. Oblak             25         europe           2021       GK       right
# D. Godín             32  south america           2019       DF       right
# David Silva          32         europe           2020       MF        left
# N. Kanté             27         europe           2023       MF       right
# M. ter Stegen        26         europe           2022       GK       right
# T. Courtois          26         europe           2024       GK        left
# Sergio Busquets      29         europe           2023       MF       right
# E. Cavani            31  south america           2020       ST       right
# M. Neuer             32         europe           2021       GK       right
# G. Chiellini         33         europe           2020       DF        left
# M. Salah             26         africa           2023       MF        left
# Casemiro             26  south america           2021       MF       right
# L. Insigne           27         europe           2022       ST       right
# Isco                 26         europe           2022       ST       right
# Coutinho             26  south america           2023       ST       right
# P. Aubameyang        29         africa           2021       MF       right
# M. Hummels           29         europe           2021       DF       right
# H. Lloris            31         europe           2022       GK        left
# G. Higuaín           30  south america           2019       ST       right
# G. Buffon            40         europe           2019       GK       right
# S. Umtiti            24         europe           2023       DF        left
# K. Koulibaly         27         africa           2021       DF       right
# P. Pogba             25         europe           2021       MF       right
# R. Lukaku            25         europe           2022       ST        left
# Jordi Alba           29         europe           2020       DF        left
# D. Mertens           31         europe           2020       ST       right
# ...                 ...            ...            ...      ...         ...
# M. Schantl           17         europe           2021       MF       right
# P. Paya              18         europe           2021       MF       right
# E. Bilen             17           asia           2021       GK       right
# S. Dawood            19           asia           2021       DF       right
# J. Granlund          18         europe           2020       GK       right
# B. Arapovic          19         europe           2019       MF       right
# P. Żyra              20         europe           2020       MF       right
# H. Bernat            17         europe           2021       GK       right
# V. Smedsrud          18         europe           2019       GK       right
# O. Ollikainen        17         europe           2019       MF       right
# G. Tegue             18  south america           2021       DF        left
# J. Lindstrøm         18         europe           2021       MF       right
# M. Al Qaydhi         20           asia           2021       DF        left
# G. Figliuzzi         17         europe           2021       GK       right
# N. Stephan           17         europe           2020       GK       right
# J. Garcia Sossa      18  south america           2019       MF        left
# M. Harsman           18         europe           2019       GK       right
# J. Yabur             19  south america           2021       MF       right
# M. Dyrmose           17         europe           2021       DF        left
# T. Lawal             18         europe           2021       GK       right
# D. Szczepaniak       18         europe           2019       GK       right
# T. Gundelund         16         europe           2020       DF       right
# M. Frøkjær-Jensen    18         europe           2021       MF       right
# Nicolas Firmino      17  south america           2021       MF       right
# Y. Uchimura          33           asia           2021       MF       right
# S. Adewusi           18         africa           2019       MF       right
# C. Ehlich            19         europe           2020       DF       right
# N. Fuentes           18  south america           2021       DF       right
# J. Milli             18         europe           2021       GK       right
# N. Christoffersson   19         europe           2020       ST       right
#
#                     reputation  stat_overall  stat_potential  \
# L. Messi                   5.0            94              94
# De Gea                     4.0            91              93
# L. Suárez                  5.0            91              91
# Sergio Ramos               4.0            91              91
# J. Oblak                   3.0            90              93
# D. Godín                   3.0            90              90
# David Silva                4.0            90              90
# N. Kanté                   3.0            89              90
# M. ter Stegen              3.0            89              92
# T. Courtois                4.0            89              90
# Sergio Busquets            4.0            89              89
# E. Cavani                  4.0            89              89
# M. Neuer                   5.0            89              89
# G. Chiellini               4.0            89              89
# M. Salah                   3.0            88              89
# Casemiro                   3.0            88              90
# L. Insigne                 3.0            88              88
# Isco                       3.0            88              91
# Coutinho                   3.0            88              89
# P. Aubameyang              3.0            88              88
# M. Hummels                 4.0            88              88
# H. Lloris                  4.0            88              88
# G. Higuaín                 4.0            88              88
# G. Buffon                  4.0            88              88
# S. Umtiti                  3.0            87              92
# K. Koulibaly               3.0            87              90
# P. Pogba                   4.0            87              91
# R. Lukaku                  3.0            87              89
# Jordi Alba                 3.0            87              87
# D. Mertens                 3.0            87              87
# ...                        ...           ...             ...
# M. Schantl                 1.0            50              67
# P. Paya                    1.0            50              67
# E. Bilen                   1.0            50              69
# S. Dawood                  1.0            50              62
# J. Granlund                1.0            50              65
# B. Arapovic                1.0            50              64
# P. Żyra                    1.0            50              60
# H. Bernat                  1.0            50              71
# V. Smedsrud                1.0            50              64
# O. Ollikainen              1.0            50              64
# G. Tegue                   1.0            50              68
# J. Lindstrøm               1.0            50              65
# M. Al Qaydhi               1.0            50              58
# G. Figliuzzi               1.0            49              69
# N. Stephan                 1.0            49              67
# J. Garcia Sossa            1.0            49              70
# M. Harsman                 1.0            49              65
# J. Yabur                   1.0            49              62
# M. Dyrmose                 1.0            49              69
# T. Lawal                   1.0            48              69
# D. Szczepaniak             1.0            48              63
# T. Gundelund               1.0            48              66
# M. Frøkjær-Jensen          1.0            48              63
# Nicolas Firmino            1.0            48              70
# Y. Uchimura                1.0            48              48
# S. Adewusi                 1.0            48              63
# C. Ehlich                  1.0            47              59
# N. Fuentes                 1.0            47              64
# J. Milli                   1.0            47              65
# N. Christoffersson         1.0            47              63
#
#                     stat_skill_moves        value cut_age cut_overall
# L. Messi                         4.0  110500000.0   30-34       90-94
# De Gea                           1.0   72000000.0   25-29       90-94
# L. Suárez                        3.0   80000000.0   30-34       90-94
# Sergio Ramos                     3.0   51000000.0   30-34       90-94
# J. Oblak                         1.0   68000000.0   25-29       90-94
# D. Godín                         2.0   44000000.0   30-34       90-94
# David Silva                      4.0   60000000.0   30-34       90-94
# N. Kanté                         2.0   63000000.0   25-29       80-89
# M. ter Stegen                    1.0   58000000.0   25-29       80-89
# T. Courtois                      1.0   53500000.0   25-29       80-89
# Sergio Busquets                  3.0   51500000.0   25-29       80-89
# E. Cavani                        3.0   60000000.0   30-34       80-89
# M. Neuer                         1.0   38000000.0   30-34       80-89
# G. Chiellini                     2.0   27000000.0   30-34       80-89
# M. Salah                         4.0   69500000.0   25-29       80-89
# Casemiro                         2.0   59500000.0   25-29       80-89
# L. Insigne                       4.0   62000000.0   25-29       80-89
# Isco                             4.0   73500000.0   25-29       80-89
# Coutinho                         5.0   69500000.0   25-29       80-89
# P. Aubameyang                    4.0   59000000.0   25-29       80-89
# M. Hummels                       3.0   46000000.0   25-29       80-89
# H. Lloris                        1.0   36000000.0   30-34       80-89
# G. Higuaín                       3.0   57000000.0   30-34       80-89
# G. Buffon                        1.0    4000000.0      40       80-89
# S. Umtiti                        2.0   57000000.0   20-24       80-89
# K. Koulibaly                     2.0   51000000.0   25-29       80-89
# P. Pogba                         5.0   64000000.0   25-29       80-89
# R. Lukaku                        3.0   62500000.0   25-29       80-89
# Jordi Alba                       3.0   38000000.0   25-29       80-89
# D. Mertens                       4.0   45000000.0   30-34       80-89
# ...                              ...          ...     ...         ...
# M. Schantl                       2.0      60000.0   15-19       50-59
# P. Paya                          2.0      50000.0   15-19       50-59
# E. Bilen                         1.0      50000.0   15-19       50-59
# S. Dawood                        2.0      50000.0   15-19       50-59
# J. Granlund                      1.0      50000.0   15-19       50-59
# B. Arapovic                      2.0      60000.0   15-19       50-59
# P. Żyra                          2.0      50000.0   20-24       50-59
# H. Bernat                        1.0      50000.0   15-19       50-59
# V. Smedsrud                      1.0      50000.0   15-19       50-59
# O. Ollikainen                    2.0      60000.0   15-19       50-59
# G. Tegue                         2.0      50000.0   15-19       50-59
# J. Lindstrøm                     2.0      60000.0   15-19       50-59
# M. Al Qaydhi                     2.0      40000.0   20-24       50-59
# G. Figliuzzi                     1.0      50000.0   15-19       46-49
# N. Stephan                       1.0      50000.0   15-19       46-49
# J. Garcia Sossa                  2.0      70000.0   15-19       46-49
# M. Harsman                       1.0      50000.0   15-19       46-49
# J. Yabur                         2.0      50000.0   15-19       46-49
# M. Dyrmose                       2.0      50000.0   15-19       46-49
# T. Lawal                         1.0      60000.0   15-19       46-49
# D. Szczepaniak                   1.0      50000.0   15-19       46-49
# T. Gundelund                     2.0      50000.0   15-19       46-49
# M. Frøkjær-Jensen                2.0      60000.0   15-19       46-49
# Nicolas Firmino                  2.0      60000.0   15-19       46-49
# Y. Uchimura                      2.0      20000.0   30-34       46-49
# S. Adewusi                       3.0      60000.0   15-19       46-49
# C. Ehlich                        2.0      40000.0   15-19       46-49
# N. Fuentes                       2.0      50000.0   15-19       46-49
# J. Milli                         1.0      50000.0   15-19       46-49
# N. Christoffersson               2.0      60000.0   15-19       46-49
#
# [8932 rows x 12 columns]

# %%
train_data.contract_until.value_counts()
# Out:
# 2019    2899
# 2021    2308
# 2020    2051
# 2022     761
# 2023     506
# 2018     391
# 2024      12
# 2025       3
# 2026       1
# Name: contract_until, dtype: int64

# %%
# 재계약 기간에 따른 정리
contract_df = train_data.groupby('contract_until').sum()
contract_df
# Out:
#                   age  reputation  stat_overall  stat_potential  \
# contract_until
# 2018            10398       407.0         25529           26955
# 2019            75050      3238.0        192563          205488
# 2020            51881      2316.0        137647          147093
# 2021            56415      2578.0        153021          166253
# 2022            18458       947.0         53893           58032
# 2023            12617       589.0         35343           37883
# 2024              267        19.0           964            1033
# 2025               59         4.0           213             252
# 2026               23         3.0            85              90
#
#                 stat_skill_moves         value
# contract_until
# 2018                       890.0  5.029850e+08
# 2019                      6858.0  5.062010e+09
# 2020                      4907.0  4.916320e+09
# 2021                      5471.0  6.525970e+09
# 2022                      1982.0  4.489195e+09
# 2023                      1295.0  2.935870e+09
# 2024                        35.0  2.941000e+08
# 2025                        11.0  4.216000e+07
# 2026                         3.0  5.050000e+07

# %%
# 남은 계약기간 총합
con_value = train_data['contract_until'].value_counts()
con_value
# Out:
# 2019    2899
# 2021    2308
# 2020    2051
# 2022     761
# 2023     506
# 2018     391
# 2024      12
# 2025       3
# 2026       1
# Name: contract_until, dtype: int64

# %%
# 이거 간략하게 할 것

con_value.plot(kind = 'bar')
plt.show()

# %%
train_data['prefer_foot'].value_counts()
# Out:
# right    6837
# left     2095
# Name: prefer_foot, dtype: int64

# %% [markdown]
# ### 4.4 reputation 카테고리화

# %%
def reputation(x) : 
    if x == 1 : 
        return '*'
    elif x == 2 : 
        return '**'
    elif x == 3 : 
        return '***'
    elif x == 4 :
        return '****'
    else : 
        return '*****'

# %%
#  인기도 범주화

train_data['cat_reputation']= train_data['reputation'].apply(lambda x : int(x)).apply(lambda x : reputation(x))
train_data
# Out:
#                     age      continent contract_until position prefer_foot  \
# L. Messi             31  south america           2021       ST        left
# De Gea               27         europe           2020       GK       right
# L. Suárez            31  south america           2021       ST       right
# Sergio Ramos         32         europe           2020       DF       right
# J. Oblak             25         europe           2021       GK       right
# D. Godín             32  south america           2019       DF       right
# David Silva          32         europe           2020       MF        left
# N. Kanté             27         europe           2023       MF       right
# M. ter Stegen        26         europe           2022       GK       right
# T. Courtois          26         europe           2024       GK        left
# Sergio Busquets      29         europe           2023       MF       right
# E. Cavani            31  south america           2020       ST       right
# M. Neuer             32         europe           2021       GK       right
# G. Chiellini         33         europe           2020       DF        left
# M. Salah             26         africa           2023       MF        left
# Casemiro             26  south america           2021       MF       right
# L. Insigne           27         europe           2022       ST       right
# Isco                 26         europe           2022       ST       right
# Coutinho             26  south america           2023       ST       right
# P. Aubameyang        29         africa           2021       MF       right
# M. Hummels           29         europe           2021       DF       right
# H. Lloris            31         europe           2022       GK        left
# G. Higuaín           30  south america           2019       ST       right
# G. Buffon            40         europe           2019       GK       right
# S. Umtiti            24         europe           2023       DF        left
# K. Koulibaly         27         africa           2021       DF       right
# P. Pogba             25         europe           2021       MF       right
# R. Lukaku            25         europe           2022       ST        left
# Jordi Alba           29         europe           2020       DF        left
# D. Mertens           31         europe           2020       ST       right
# ...                 ...            ...            ...      ...         ...
# M. Schantl           17         europe           2021       MF       right
# P. Paya              18         europe           2021       MF       right
# E. Bilen             17           asia           2021       GK       right
# S. Dawood            19           asia           2021       DF       right
# J. Granlund          18         europe           2020       GK       right
# B. Arapovic          19         europe           2019       MF       right
# P. Żyra              20         europe           2020       MF       right
# H. Bernat            17         europe           2021       GK       right
# V. Smedsrud          18         europe           2019       GK       right
# O. Ollikainen        17         europe           2019       MF       right
# G. Tegue             18  south america           2021       DF        left
# J. Lindstrøm         18         europe           2021       MF       right
# M. Al Qaydhi         20           asia           2021       DF        left
# G. Figliuzzi         17         europe           2021       GK       right
# N. Stephan           17         europe           2020       GK       right
# J. Garcia Sossa      18  south america           2019       MF        left
# M. Harsman           18         europe           2019       GK       right
# J. Yabur             19  south america           2021       MF       right
# M. Dyrmose           17         europe           2021       DF        left
# T. Lawal             18         europe           2021       GK       right
# D. Szczepaniak       18         europe           2019       GK       right
# T. Gundelund         16         europe           2020       DF       right
# M. Frøkjær-Jensen    18         europe           2021       MF       right
# Nicolas Firmino      17  south america           2021       MF       right
# Y. Uchimura          33           asia           2021       MF       right
# S. Adewusi           18         africa           2019       MF       right
# C. Ehlich            19         europe           2020       DF       right
# N. Fuentes           18  south america           2021       DF       right
# J. Milli             18         europe           2021       GK       right
# N. Christoffersson   19         europe           2020       ST       right
#
#                     reputation  stat_overall  stat_potential  \
# L. Messi                   5.0            94              94
# De Gea                     4.0            91              93
# L. Suárez                  5.0            91              91
# Sergio Ramos               4.0            91              91
# J. Oblak                   3.0            90              93
# D. Godín                   3.0            90              90
# David Silva                4.0            90              90
# N. Kanté                   3.0            89              90
# M. ter Stegen              3.0            89              92
# T. Courtois                4.0            89              90
# Sergio Busquets            4.0            89              89
# E. Cavani                  4.0            89              89
# M. Neuer                   5.0            89              89
# G. Chiellini               4.0            89              89
# M. Salah                   3.0            88              89
# Casemiro                   3.0            88              90
# L. Insigne                 3.0            88              88
# Isco                       3.0            88              91
# Coutinho                   3.0            88              89
# P. Aubameyang              3.0            88              88
# M. Hummels                 4.0            88              88
# H. Lloris                  4.0            88              88
# G. Higuaín                 4.0            88              88
# G. Buffon                  4.0            88              88
# S. Umtiti                  3.0            87              92
# K. Koulibaly               3.0            87              90
# P. Pogba                   4.0            87              91
# R. Lukaku                  3.0            87              89
# Jordi Alba                 3.0            87              87
# D. Mertens                 3.0            87              87
# ...                        ...           ...             ...
# M. Schantl                 1.0            50              67
# P. Paya                    1.0            50              67
# E. Bilen                   1.0            50              69
# S. Dawood                  1.0            50              62
# J. Granlund                1.0            50              65
# B. Arapovic                1.0            50              64
# P. Żyra                    1.0            50              60
# H. Bernat                  1.0            50              71
# V. Smedsrud                1.0            50              64
# O. Ollikainen              1.0            50              64
# G. Tegue                   1.0            50              68
# J. Lindstrøm               1.0            50              65
# M. Al Qaydhi               1.0            50              58
# G. Figliuzzi               1.0            49              69
# N. Stephan                 1.0            49              67
# J. Garcia Sossa            1.0            49              70
# M. Harsman                 1.0            49              65
# J. Yabur                   1.0            49              62
# M. Dyrmose                 1.0            49              69
# T. Lawal                   1.0            48              69
# D. Szczepaniak             1.0            48              63
# T. Gundelund               1.0            48              66
# M. Frøkjær-Jensen          1.0            48              63
# Nicolas Firmino            1.0            48              70
# Y. Uchimura                1.0            48              48
# S. Adewusi                 1.0            48              63
# C. Ehlich                  1.0            47              59
# N. Fuentes                 1.0            47              64
# J. Milli                   1.0            47              65
# N. Christoffersson         1.0            47              63
#
#                     stat_skill_moves        value cut_age cut_overall  \
# L. Messi                         4.0  110500000.0   30-34       90-94
# De Gea                           1.0   72000000.0   25-29       90-94
# L. Suárez                        3.0   80000000.0   30-34       90-94
# Sergio Ramos                     3.0   51000000.0   30-34       90-94
# J. Oblak                         1.0   68000000.0   25-29       90-94
# D. Godín                         2.0   44000000.0   30-34       90-94
# David Silva                      4.0   60000000.0   30-34       90-94
# N. Kanté                         2.0   63000000.0   25-29       80-89
# M. ter Stegen                    1.0   58000000.0   25-29       80-89
# T. Courtois                      1.0   53500000.0   25-29       80-89
# Sergio Busquets                  3.0   51500000.0   25-29       80-89
# E. Cavani                        3.0   60000000.0   30-34       80-89
# M. Neuer                         1.0   38000000.0   30-34       80-89
# G. Chiellini                     2.0   27000000.0   30-34       80-89
# M. Salah                         4.0   69500000.0   25-29       80-89
# Casemiro                         2.0   59500000.0   25-29       80-89
# L. Insigne                       4.0   62000000.0   25-29       80-89
# Isco                             4.0   73500000.0   25-29       80-89
# Coutinho                         5.0   69500000.0   25-29       80-89
# P. Aubameyang                    4.0   59000000.0   25-29       80-89
# M. Hummels                       3.0   46000000.0   25-29       80-89
# H. Lloris                        1.0   36000000.0   30-34       80-89
# G. Higuaín                       3.0   57000000.0   30-34       80-89
# G. Buffon                        1.0    4000000.0      40       80-89
# S. Umtiti                        2.0   57000000.0   20-24       80-89
# K. Koulibaly                     2.0   51000000.0   25-29       80-89
# P. Pogba                         5.0   64000000.0   25-29       80-89
# R. Lukaku                        3.0   62500000.0   25-29       80-89
# Jordi Alba                       3.0   38000000.0   25-29       80-89
# D. Mertens                       4.0   45000000.0   30-34       80-89
# ...                              ...          ...     ...         ...
# M. Schantl                       2.0      60000.0   15-19       50-59
# P. Paya                          2.0      50000.0   15-19       50-59
# E. Bilen                         1.0      50000.0   15-19       50-59
# S. Dawood                        2.0      50000.0   15-19       50-59
# J. Granlund                      1.0      50000.0   15-19       50-59
# B. Arapovic                      2.0      60000.0   15-19       50-59
# P. Żyra                          2.0      50000.0   20-24       50-59
# H. Bernat                        1.0      50000.0   15-19       50-59
# V. Smedsrud                      1.0      50000.0   15-19       50-59
# O. Ollikainen                    2.0      60000.0   15-19       50-59
# G. Tegue                         2.0      50000.0   15-19       50-59
# J. Lindstrøm                     2.0      60000.0   15-19       50-59
# M. Al Qaydhi                     2.0      40000.0   20-24       50-59
# G. Figliuzzi                     1.0      50000.0   15-19       46-49
# N. Stephan                       1.0      50000.0   15-19       46-49
# J. Garcia Sossa                  2.0      70000.0   15-19       46-49
# M. Harsman                       1.0      50000.0   15-19       46-49
# J. Yabur                         2.0      50000.0   15-19       46-49
# M. Dyrmose                       2.0      50000.0   15-19       46-49
# T. Lawal                         1.0      60000.0   15-19       46-49
# D. Szczepaniak                   1.0      50000.0   15-19       46-49
# T. Gundelund                     2.0      50000.0   15-19       46-49
# M. Frøkjær-Jensen                2.0      60000.0   15-19       46-49
# Nicolas Firmino                  2.0      60000.0   15-19       46-49
# Y. Uchimura                      2.0      20000.0   30-34       46-49
# S. Adewusi                       3.0      60000.0   15-19       46-49
# C. Ehlich                        2.0      40000.0   15-19       46-49
# N. Fuentes                       2.0      50000.0   15-19       46-49
# J. Milli                         1.0      50000.0   15-19       46-49
# N. Christoffersson               2.0      60000.0   15-19       46-49
#
#                    cat_reputation
# L. Messi                    *****
# De Gea                       ****
# L. Suárez                   *****
# Sergio Ramos                 ****
# J. Oblak                      ***
# D. Godín                      ***
# David Silva                  ****
# N. Kanté                      ***
# M. ter Stegen                 ***
# T. Courtois                  ****
# Sergio Busquets              ****
# E. Cavani                    ****
# M. Neuer                    *****
# G. Chiellini                 ****
# M. Salah                      ***
# Casemiro                      ***
# L. Insigne                    ***
# Isco                          ***
# Coutinho                      ***
# P. Aubameyang                 ***
# M. Hummels                   ****
# H. Lloris                    ****
# G. Higuaín                   ****
# G. Buffon                    ****
# S. Umtiti                     ***
# K. Koulibaly                  ***
# P. Pogba                     ****
# R. Lukaku                     ***
# Jordi Alba                    ***
# D. Mertens                    ***
# ...                           ...
# M. Schantl                      *
# P. Paya                         *
# E. Bilen                        *
# S. Dawood                       *
# J. Granlund                     *
# B. Arapovic                     *
# P. Żyra                         *
# H. Bernat                       *
# V. Smedsrud                     *
# O. Ollikainen                   *
# G. Tegue                        *
# J. Lindstrøm                    *
# M. Al Qaydhi                    *
# G. Figliuzzi                    *
# N. Stephan                      *
# J. Garcia Sossa                 *
# M. Harsman                      *
# J. Yabur                        *
# M. Dyrmose                      *
# T. Lawal                        *
# D. Szczepaniak                  *
# T. Gundelund                    *
# M. Frøkjær-Jensen               *
# Nicolas Firmino                 *
# Y. Uchimura                     *
# S. Adewusi                      *
# C. Ehlich                       *
# N. Fuentes                      *
# J. Milli                        *
# N. Christoffersson              *
#
# [8932 rows x 13 columns]

# %%
train_data.head()
# Out:
#               age      continent contract_until         position prefer_foot  \
# L. Messi       31  south america           2021   ST  left  foot        left
# De Gea         27         europe           2020  GK  right  foot       right
# L. Suárez      31  south america           2021  ST  right  foot       right
# Sergio Ramos   32         europe           2020  DF  right  foot       right
# J. Oblak       25         europe           2021  GK  right  foot       right
#
#               reputation  stat_overall  stat_potential  stat_skill_moves  \
# L. Messi             5.0            94              94               4.0
# De Gea               4.0            91              93               1.0
# L. Suárez            5.0            91              91               3.0
# Sergio Ramos         4.0            91              91               3.0
# J. Oblak             3.0            90              93               1.0
#
#                     value cut_age cut_overall cat_reputation
# L. Messi      110500000.0   30-34       90-94          *****
# De Gea         72000000.0   25-29       90-94           ****
# L. Suárez      80000000.0   30-34       90-94          *****
# Sergio Ramos   51000000.0   30-34       90-94           ****
# J. Oblak       68000000.0   25-29       90-94            ***

# %%
# position과 prefer_foot 변수 합치기

position = train_data['position']
train_data['position'] = position +'  '+ train_data['prefer_foot'] +'  '+'foot'

# %% [markdown]
# 변수별 중요도 측정 - 의사결정나무
#
# 일정 나이가 지난 선수는 stat_overall을,
#
# 어린 유망주들은 stat_potential을 치중해서 비교해보기

# %%
# 인기도별 stat 수치
plt.bar('cat_reputation','stat_overall',data = train_data)
plt.title('Reputation and Stat_overall Relation')
plt.xlabel('Reputation')
plt.ylabel('stat_ovarall')

plt.show()

# %%
plt.figure(figsize = (8,6))

plt.scatter('age','value',data = train_data)

plt.show()
